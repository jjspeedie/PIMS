# %% [markdown]
# # Streamlines in the disk frame

# %% [markdown]
# In this notebook, we'll walk through how to generate a streamline using the **Pineda Implementation of the Mendoza Streamline model**, ``PIMS``. The analytic model was presented by [Mendoza et al. (2009)](https://ui.adsabs.harvard.edu/abs/2009MNRAS.393..579M/abstract). The code implementation was first used to interpret observations by [Pineda et al. (2020)](https://ui.adsabs.harvard.edu/abs/2020NatAs...4.1158P/abstract), and later by [Valdivia-Mena et al. (2022)](https://ui.adsabs.harvard.edu/abs/2022A%26A...667A..12V/abstract).
# The code [``TIPSY``](https://github.com/AashishGpta/TIPSY) is an independent implementation of the same Mendoza model, presented by [Gupta et al. (2024)](https://ui.adsabs.harvard.edu/abs/2024arXiv240110403G/abstract).

# %% [markdown]
# ## The disk frame coordinate system

# %% [markdown]
# ## Generate a streamline

# %%
import sys, os
sys.path.append('/Users/jspeedie/Documents/RESEARCH/MSC5/code/PIMS/')
from pims import streamline

# %%
mass        = 2.     # Msun
omega       = 8e-12  # Hz
r0          = 1000   # au
theta0      = 45     # deg
phi0        = 0      # deg
v_r0        = 0      # km/s
# rmin        = 50     # au (optional)
# delta_r     = 10     # au (optional)

# %%
streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)

# %% [markdown]
# ### Accessing the streamline's attributes

# %%
print(streamer)

# %% [markdown]
# ## View the streamline trajectory in the disk frame (x,y,z)

# %%
streamer.plot_xyz()

# %% [markdown]
# Streamer is the orange line and its trajectory lies in a plane. It starts from the red dot and ends at the blue dot. The purple circle is the centrifugal radius. The faint orange line is the projection of the streamline onto the xy plane.

# %% [markdown]
# ## Understanding the model's properties

# %% [markdown]
# ### Centrifugal radius

# %% [markdown]
# ### Varying the central mass

# %% [markdown]
# ### Varying the initial radial velocity

# %% [markdown]
# ### Varying the initial radius

# %% [markdown]
# ### Varying the initial azimuthal position

# %% [markdown]
# ### Varying the initial polar angle

# %% [markdown]
# ## Understanding the model's limitations

# %% [markdown]
# ### Undefined initial starting locations

# %% [markdown]
# #### Maximum initial angular velocity

# %% [markdown]
# #### Cannot initialize directly on the midplane

# %% [markdown]
# #### Cannot initialize directly on the z-axis

# %% [markdown]
# ### Recognizing insufficient radial resolution (``delta_r`` is too big)

# %% [markdown]
# ### Maximum azimuthal distance traversed before hitting the midplane

# %%
mass        = 2.     # Msun
omega       = 8e-12  # Hz
r0          = 1000   # au
v_r0        = 0      # km/s

theta0      = 45     # deg
phi0        = 0      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
# Out:
# mu =  0.807262131763563
# nu =  0.0
# p =  403.63106588178135 AU
# epsilon =  -1.2886881888374
# self.ecc =  0.5963689341182186
# ***This should be between -1 and 1:  1.0
# Initial orb_ang:  0.0 rad
# tolerance  5.796705408411451e-13
# np.tan(theta0) / np.tan(theta):  [1.         0.98907376 0.97814873 0.96722341 0.95629627 0.94536576
#  0.93443033 0.92348835 0.91253822 0.90157827 0.89060679 0.87962208
#  0.86862235 0.8576058  0.84657058 0.83551479 0.82443649 0.81333368
#  0.8022043  0.79104624 0.77985733 0.76863534 0.75737794 0.74608275
#  0.7347473  0.72336905 0.71194536 0.70047347 0.68895056 0.67737367
#  0.66573973 0.65404555 0.6422878  0.63046302 0.61856757 0.60659766
#  0.59454935 0.58241847 0.57020066 0.55789136 0.54548576 0.5329788
#  0.52036514 0.50763915 0.49479489 0.48182606 0.468726   0.45548762
#  0.44210341 0.42856537 0.41486496 0.40099309 0.38694    0.37269526
#  0.35824768 0.3435852  0.32869487 0.31356266 0.29817343 0.28251075
#  0.26655676 0.25029199 0.23369521 0.21674314 0.19941021 0.18166826
#  0.16348616 0.14482939 0.12565953 0.10593364 0.08560356 0.06461503
#  0.0429066  0.02040834]
# Disk inclination `inc` and position angle `pa` were not provided.
# Distance `dist` and systemic velocity `v_sys` may have been provided, but will not be used.

# %%
mass        = 2.     # Msun
omega       = 8e-12  # Hz
r0          = 1000   # au
v_r0        = 0      # km/s

theta0      = 80      # deg
phi0        = 0      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])
# Out:
# mu =  0.807262131763563
# nu =  0.0
# p =  782.9202000108422 AU
# epsilon =  -0.9825024338656182
# self.ecc =  0.21707979998915783
# ***This should be between -1 and 1:  0.9999999999999994
# Initial orb_ang:  3.332000937312528e-08 rad
# tolerance  5.796705408411451e-13
# np.tan(theta0) / np.tan(theta):  [1.00000000e+00 9.69776722e-01 9.39139502e-01 9.08077154e-01
#  8.76578023e-01 8.44629961e-01 8.12220297e-01 7.79335810e-01
#  7.45962694e-01 7.12086526e-01 6.77692224e-01 6.42764011e-01
#  6.07285371e-01 5.71238998e-01 5.34606751e-01 4.97369596e-01
#  4.59507548e-01 4.20999604e-01 3.81823679e-01 3.41956524e-01
#  3.01373649e-01 2.60049229e-01 2.17956010e-01 1.75065198e-01
#  1.31346347e-01 8.67672265e-02 4.12936826e-02 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16]
# Disk inclination `inc` and position angle `pa` were not provided.
# Distance `dist` and systemic velocity `v_sys` may have been provided, but will not be used.
# 89.99999999999997 deg

# %%
mass        = 2.     # Msun
omega       = 8e-12  # Hz
r0          = 1000   # au
v_r0        = 0      # km/s

theta0      = 80      # deg
phi0        = 335      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()


print(streamer.phi[-1]-streamer.phi[0])
# print('streamer.r: ', streamer.r)
print('streamer.z: ', streamer.z)

# import numpy as np
# print(np.cos(streamer.theta)/np.cos(streamer.theta0))

# Equation 8 of Mendoza forces the orbital angle to follow np.cos(streamer.theta)/np.cos(streamer.theta0).
# Out:
# mu =  0.807262131763563
# nu =  0.0
# p =  782.9202000108422 AU
# epsilon =  -0.9825024338656182
# self.ecc =  0.21707979998915783
# ***This should be between -1 and 1:  0.9999999999999994
# Initial orb_ang:  3.332000937312528e-08 rad
# tolerance  5.796705408411451e-13
# np.tan(theta0) / np.tan(theta):  [1.00000000e+00 9.69776722e-01 9.39139502e-01 9.08077154e-01
#  8.76578023e-01 8.44629961e-01 8.12220297e-01 7.79335810e-01
#  7.45962694e-01 7.12086526e-01 6.77692224e-01 6.42764011e-01
#  6.07285371e-01 5.71238998e-01 5.34606751e-01 4.97369596e-01
#  4.59507548e-01 4.20999604e-01 3.81823679e-01 3.41956524e-01
#  3.01373649e-01 2.60049229e-01 2.17956010e-01 1.75065198e-01
#  1.31346347e-01 8.67672265e-02 4.12936826e-02 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16 3.47265856e-16 3.47265856e-16
#  3.47265856e-16 3.47265856e-16]
# Disk inclination `inc` and position angle `pa` were not provided.
# Distance `dist` and systemic velocity `v_sys` may have been provided, but will not be used.
# 90.0 deg
# streamer.z:  [1.73648178e+02 1.67190664e+02 1.60733150e+02 1.54275636e+02
#  1.47818122e+02 1.41360608e+02 1.34903093e+02 1.28445579e+02
#  1.21988064e+02 1.15530550e+02 1.09073035e+02 1.02615521e+02
#  9.61580064e+01 8.97004919e+01 8.32429774e+01 7.67854629e+01
#  7.03279483e+01 6.38704337e+01 5.74129192e+01 5.09554046e+01
#  4.44978900e+01 3.80403754e+01 3.15828608e+01 2.51253462e+01
#  1.86678316e+01 1.22103169e+01 5.75280227e+00 4.78860916e-14
#  4.73917862e-14 4.68974807e-14 4.64031752e-14 4.59088697e-14
#  4.54145642e-14 4.49202587e-14 4.44259532e-14 4.39316477e-14
#  4.34373422e-14 4.29430367e-14 4.24487312e-14 4.19544257e-14
#  4.14601202e-14 4.09658147e-14 4.04715093e-14 3.99772038e-14
#  3.94828983e-14 3.89885928e-14 3.84942873e-14 3.79999818e-14
#  3.75056763e-14 3.70113708e-14 3.65170653e-14 3.60227598e-14
#  3.55284543e-14 3.50341488e-14 3.45398433e-14 3.40455378e-14
#  3.35512324e-14 3.30569269e-14 3.25626214e-14 3.20683159e-14
#  3.15740104e-14 3.10797049e-14 3.05853994e-14 3.00910939e-14
#  2.95967884e-14 2.91024829e-14 2.86081774e-14 2.81138719e-14
#  2.76195664e-14 2.71252609e-14 2.66309555e-14 2.61366500e-14
#  2.56423445e-14 2.51480390e-14] AU

# %%
import matplotlib.pyplot as plt
import numpy as np
# plt.plot(np.arange(len(streamer.theta)), streamer.theta)
# plt.plot(np.arange(len(streamer.z)), streamer.z/300)
# print(streamer.theta)
# print(streamer.z)
# print(streamer.r/streamer.r_cent)
import matplotlib.pyplot as plt
plt.plot(streamer.r, streamer.z)
plt.scatter([782.9202000108422], [0])

# %%
plt.plot(streamer.r, np.degrees(streamer.phi-streamer.phi0))
plt.scatter([782.9202000108422], [0])

# %%
mass        = 2.     # Msun
omega       = 8e-12  # Hz
r0          = 1000   # au
v_r0        = 0      # km/s

theta0      = 40      # deg
phi0        = 335      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()


print(streamer.phi[-1]-streamer.phi[0])

# %%
sys.exit()

# %%
mass        = 2.     # Msun
omega       = 8e-12  # Hz
r0          = 1000   # au
v_r0        = 0      # km/s

theta0      = 89      # deg
phi0        = 0      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
sys.exit()

# %%
theta0      = 45     # deg
phi0        = 90      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 45     # deg
phi0        = 180      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 45     # deg
phi0        = 270      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 45     # deg
phi0        = 360      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 0     # deg
phi0        = 0      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 45     # deg
phi0        = 0      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 90     # deg
phi0        = 0      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 105     # deg
phi0        = 330      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 135     # deg
phi0        = 0      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 160     # deg
phi0        = 0      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
theta0      = 180     # deg
phi0        = 1      # deg

streamer = streamline(mass=mass, omega=omega, r0=r0, theta0=theta0, phi0=phi0,  v_r0=v_r0)
streamer.plot_xyz()
print(streamer.phi[-1]-streamer.phi[0])

# %%
# streamline(mass=mass, r0=r0, theta0=theta0, phi0=phi0, omega=omega, v_r0=v_r0,
#                        inc=inc, pa=pa, rmin=rmin, delta_r=delta_r, dist=dist, v_sys=v_sys)
